# %% [markdown]
# # Новый раздел

# %%
# main.py
import matplotlib.pyplot as pl
import sys
sys.path.append('/content/sample_data')
import data_loader as loader
import module_for_laptop as mdl
import graph
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
import seaborn as sns

# Загрузка данных
print('\nЗагрузка данных')
file_path = '/content/sample_data/dataset_laptop.csv'
dataset = loader.load_dataset(file_path, 'Brand')

mdl.encoder(dataset, ["Brand" , "Processor", "RAM (GB)", "Storage", "GPU" , "Screen Size (inch)" , "Resolution" , "Battery Life (hours)" , "Operating System" ])
print('\nВывод типов данных')
print(dataset.dtypes)
# print(dataset)
print("\nПодсчет пустых значений")
mdl.count_empty_values(dataset)


# гистограммы частоты повторений процессора
graph.hist(dataset, "Processor")

# гистограммы частоты повторений GPU
graph.hist(dataset, "GPU")

# линейный график
graph.line(dataset)

# диаграмма рассеяния
graph.scatter(dataset)
# Out:
# Загрузка данных
# Данные успешно загружены.
# Матрица признаков X:
#          Processor  RAM (GB)    Storage                 GPU  \
# 0      AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1      AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2         Intel i5        32    2TB SSD     Nvidia RTX 3060
# 3         Intel i5         4  256GB SSD     Nvidia RTX 3080
# 4         Intel i3         4  256GB SSD  AMD Radeon RX 6600
# ...            ...       ...        ...                 ...
# 11763     Intel i3         4    2TB SSD     Nvidia RTX 2060
# 11764     Intel i3         4    2TB SSD  AMD Radeon RX 6800
# 11765  AMD Ryzen 9         4    2TB SSD  AMD Radeon RX 6600
# 11766  AMD Ryzen 7        16  512GB SSD          Integrated
# 11767     Intel i7         8  256GB SSD     Nvidia RTX 3080
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# 0                    17.3  2560x1440                   8.9         1.42
# ...
